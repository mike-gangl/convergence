# %% [markdown]
# # Functional Gap Reports
#
# In this notebook we'll take the fitness for task for all of the alternatives and candidates, and find the gaps from a candidate tool to the alternatives.

# %%
from math import *
import pandas as pd
import numpy as np
import sys
import os
import csv

# %%
#Read in the data
np.set_printoptions(threshold=1000)

alternatives = ['AppEEARS','Field Campaign Explorer (FCX)','OpenAltimetry','Data Access Tool','Operation IceBridge Portal','Vertex','Earthdata Search','SOOT','Airborne Data Visualizer','Giovanni','Worldview']
candidates = ['ASDC TES Subsetter','ASDC CALIPSO Subsetter','CERES Subset/Visualization Tool','ASDC MOPITT Subsetter','ACE2 Download Tool','Data Subscription and Customization Service (ECS)','Daymet Single Pixel Extraction Tool (SPET)','Model-Derived Global Aerosol Climatology for MISR Analysis ("Clim-Likely" Data Set)','MISR Browse Tool','MAPSS','DQViz','SOTO 2D','HiTIDE','Earthdata Access (508 Access tool)','Earthdata Catalog (Backed by Earthdata Access)','Spatial Data Access Tool (SDAT): Web Interface including mapwidget','Terrestrial Ecology Subsetting & Visualization Services (TESViS) Global Tool','GLIMS Glacier Viewer','MISR Customization & Order Tool','SeaBASS','ORNL DAAC Soil Moisture Visualizer (SMV)','ORNL DAAC Spatial Data Access Tool (SDAT)','SEDAC Map Viewer, POPGRID, Hazards Mapper, Pop Estimation Tool.','SEDAC map based data sub-setting and download tools.','SEDAC form based data download tools','SEDAC Map Gallery','GES DISC Data Recommender','Giovanni Mobile Application','GES DISC Subsetter','Giovanni GPT','GES DISC Publication Management System','GES DISC mEditor']
data = pd.read_csv('data/acw-scores-fitness_only.csv')
data
candidate_data = pd.read_csv('data/ccw_scores.csv')
# Dynamically generate candidate tool list
candidates = list(candidate_data.columns)[1:]
vectors = {}
candidate_vectors = {}
for x in alternatives:
  vectors[x] =  data[x].tolist()
for x in candidates:
  candidate_vectors[x] = candidate_data[x].tolist()

# %% [markdown]
# # Identify Functional Gaps

# %%
# Setup our result array (there are 11 alternatives, so we create an 11x11 matrix)
candidate_results =  np.zeros((len(candidates),11 ))

# %%
def sanitize(key):
    return key.replace('/','-').replace(' ','_')

# %%
# Iterate over the whole thing
import csv 
try:
    os.makedirs('reports')
except:
    pass
for i,k in enumerate(candidate_vectors.keys()):
    with open('reports/'+sanitize(k)+'_gap_report.csv','w', newline='', encoding='utf-8') as csvfile:
      
      data= [
          ['alternative','missing function']
      ]
    
      for j, alternative in enumerate(alternatives):
        if k == alternative:
          score = 0
          score_naive = 0
        else:
          idxlist = np.nonzero(candidate_vectors[k])[0]
          for idx in idxlist:
              if candidate_vectors[k][idx] > vectors[alternative][idx]:
                  data.append([sanitize(alternative),candidate_data['Criteria'][idx] ])
                  # f.write('{},'{}'\n'.format(sanitize(alternative), candidate_data['Criteria'][idx]))
                  #print('{},{} '.format(alternative, candidate_data['Criteria'][idx]))      
    
      writer = csv.writer(csvfile)
      writer.writerows(data)

# %% [markdown]
# # Example Report Output

# %%
pd.set_option('display.max_columns', None)  # or 1000
pd.set_option('display.max_rows', None)  # or 1000
pd.set_option('display.max_colwidth', None)  # or 199
report = pd.read_csv('reports/Daymet_Single_Pixel_Extraction_Tool_(SPET)_gap_report.csv')
report
# Out:
#                       alternative  \
# 0                        AppEEARS
# 1                        AppEEARS
# 2                        AppEEARS
# 3                        AppEEARS
# 4   Field_Campaign_Explorer_(FCX)
# 5   Field_Campaign_Explorer_(FCX)
# 6   Field_Campaign_Explorer_(FCX)
# 7   Field_Campaign_Explorer_(FCX)
# 8   Field_Campaign_Explorer_(FCX)
# 9   Field_Campaign_Explorer_(FCX)
# 10  Field_Campaign_Explorer_(FCX)
# 11  Field_Campaign_Explorer_(FCX)
# 12  Field_Campaign_Explorer_(FCX)
# 13  Field_Campaign_Explorer_(FCX)
# 14                  OpenAltimetry
# 15                  OpenAltimetry
# 16                  OpenAltimetry
# 17                  OpenAltimetry
# 18                  OpenAltimetry
# 19               Data_Access_Tool
# 20               Data_Access_Tool
# 21               Data_Access_Tool
# 22               Data_Access_Tool
# 23               Data_Access_Tool
# 24               Data_Access_Tool
# 25               Data_Access_Tool
# 26               Data_Access_Tool
# 27               Data_Access_Tool
# 28               Data_Access_Tool
# 29               Data_Access_Tool
# 30               Data_Access_Tool
# 31               Data_Access_Tool
# 32               Data_Access_Tool
# 33               Data_Access_Tool
# 34               Data_Access_Tool
# 35     Operation_IceBridge_Portal
# 36     Operation_IceBridge_Portal
# 37     Operation_IceBridge_Portal
# 38     Operation_IceBridge_Portal
# 39     Operation_IceBridge_Portal
# 40     Operation_IceBridge_Portal
# 41     Operation_IceBridge_Portal
# 42     Operation_IceBridge_Portal
# 43     Operation_IceBridge_Portal
# 44     Operation_IceBridge_Portal
# 45     Operation_IceBridge_Portal
# 46     Operation_IceBridge_Portal
# 47     Operation_IceBridge_Portal
# 48     Operation_IceBridge_Portal
# 49     Operation_IceBridge_Portal
# 50     Operation_IceBridge_Portal
# 51     Operation_IceBridge_Portal
# 52                         Vertex
# 53                         Vertex
# 54                         Vertex
# 55               Earthdata_Search
# 56               Earthdata_Search
# 57               Earthdata_Search
# 58               Earthdata_Search
# 59               Earthdata_Search
# 60                           SOOT
# 61                           SOOT
# 62                           SOOT
# 63                           SOOT
# 64                           SOOT
# 65                           SOOT
# 66                           SOOT
# 67                           SOOT
# 68                           SOOT
# 69                           SOOT
# 70                           SOOT
# 71       Airborne_Data_Visualizer
# 72       Airborne_Data_Visualizer
# 73       Airborne_Data_Visualizer
# 74       Airborne_Data_Visualizer
# 75       Airborne_Data_Visualizer
# 76       Airborne_Data_Visualizer
# 77       Airborne_Data_Visualizer
# 78       Airborne_Data_Visualizer
# 79       Airborne_Data_Visualizer
# 80       Airborne_Data_Visualizer
# 81       Airborne_Data_Visualizer
# 82                       Giovanni
# 83                       Giovanni
# 84                      Worldview
# 85                      Worldview
# 86                      Worldview
# 87                      Worldview
# 88                      Worldview
# 89                      Worldview
# 90                      Worldview
# 91                      Worldview
# 92                      Worldview
# 93                      Worldview
# 94                      Worldview
#
#                                                                                                    missing function
# 0   The tool allows exporting of search, download, and/or transformation references for use in programmatic access.
# 1                                                          As a user, I can share my visualization with colleagues.
# 2                                                   As a user, I can download and save visualizations from the tool
# 3                                        Offer a formal citation for users to easily cite the tool in publications.
# 4                                                            As a user, I can search data based on Geospatial areas
# 5                                                         As a user, I can search for data based on Temporal bounds
# 6                                                     As a user, I can search for data variables based on keywords.
# 7                                                                 As a user, I can share my search with colleagues.
# 8                                                                        As a user, I can bulk download search data
# 9   The tool allows exporting of search, download, and/or transformation references for use in programmatic access.
# 10                                                         As a user, I can share my visualization with colleagues.
# 11                                                  As a user, I can download and save visualizations from the tool
# 12                                                        The UI allows for data spatial subsetting transformations
# 13                                               The UI allows the reformatting of output files into other formats.
# 14                                                    As a user, I can search for data variables based on keywords.
# 15  The tool allows exporting of search, download, and/or transformation references for use in programmatic access.
# 16                                                     As a user I can visualize data statistics for a single pixel
# 17                                                                 Ability to bulk download customized output files
# 18                                                                      Ability to re-submit the exact same request
# 19                                                    As a user, I can search for data variables based on keywords.
# 20                                                                As a user, I can share my search with colleagues.
# 21                                                                     As a user, I can acquire data via public API
# 22                                                   As a user, I can visualize data as an interactive time series.
# 23                                                      As a user, I can visualize multiple data variables at once.
# 24                                                         As a user, I can share my visualization with colleagues.
# 25                                                  As a user, I can download and save visualizations from the tool
# 26                                                     As a user I can visualize data statistics for a single pixel
# 27                                                        The UI allows for data spatial subsetting transformations
# 28                                                     The UI allows for data  temporal subsetting transformations?
# 29                                          The UI allows for data  band/layer/variable subsetting transformations?
# 30                                               The UI allows the reformatting of output files into other formats.
# 31                                                                 Ability to bulk download customized output files
# 32                                                                      Ability to re-submit the exact same request
# 33                                       Offer a formal citation for users to easily cite the tool in publications.
# 34                                                           As a user, I can complete all tasks within the tool UX
# 35                                                    As a user, I can search for data variables based on keywords.
# 36                                                                As a user, I can share my search with colleagues.
# 37                                                                     As a user, I can acquire data via public API
# 38  The tool allows exporting of search, download, and/or transformation references for use in programmatic access.
# 39                                                   As a user, I can visualize data as an interactive time series.
# 40                                                      As a user, I can visualize multiple data variables at once.
# 41                                                         As a user, I can share my visualization with colleagues.
# 42                                                  As a user, I can download and save visualizations from the tool
# 43                                                     As a user I can visualize data statistics for a single pixel
# 44                                                        The UI allows for data spatial subsetting transformations
# 45                                                     The UI allows for data  temporal subsetting transformations?
# 46                                          The UI allows for data  band/layer/variable subsetting transformations?
# 47                                               The UI allows the reformatting of output files into other formats.
# 48                                                                 Ability to bulk download customized output files
# 49                                                                      Ability to re-submit the exact same request
# 50                                       Offer a formal citation for users to easily cite the tool in publications.
# 51                                                           As a user, I can complete all tasks within the tool UX
# 52                                                  As a user, I can download and save visualizations from the tool
# 53                                               The UI allows the reformatting of output files into other formats.
# 54                                       Offer a formal citation for users to easily cite the tool in publications.
# 55  The tool allows exporting of search, download, and/or transformation references for use in programmatic access.
# 56                                                   As a user, I can visualize data as an interactive time series.
# 57                                                  As a user, I can download and save visualizations from the tool
# 58                                                     As a user I can visualize data statistics for a single pixel
# 59                                       Offer a formal citation for users to easily cite the tool in publications.
# 60                                                                As a user, I can share my search with colleagues.
# 61                                                                     As a user, I can acquire data via public API
# 62  The tool allows exporting of search, download, and/or transformation references for use in programmatic access.
# 63                                                   As a user, I can visualize data as an interactive time series.
# 64                                                      As a user, I can visualize multiple data variables at once.
# 65                                                         As a user, I can share my visualization with colleagues.
# 66                                                  As a user, I can download and save visualizations from the tool
# 67                                                     As a user I can visualize data statistics for a single pixel
# 68                                                        The UI allows for data spatial subsetting transformations
# 69                                                     The UI allows for data  temporal subsetting transformations?
# 70                                               The UI allows the reformatting of output files into other formats.
# 71                                                           As a user, I can search data based on Geospatial areas
# 72                                                    As a user, I can search for data variables based on keywords.
# 73                                                                       As a user, I can bulk download search data
# 74  The tool allows exporting of search, download, and/or transformation references for use in programmatic access.
# 75                                                  As a user, I can download and save visualizations from the tool
# 76                                                        The UI allows for data spatial subsetting transformations
# 77                                                     The UI allows for data  temporal subsetting transformations?
# 78                                          The UI allows for data  band/layer/variable subsetting transformations?
# 79                                               The UI allows the reformatting of output files into other formats.
# 80                                                                 Ability to bulk download customized output files
# 81                                                                      Ability to re-submit the exact same request
# 82                                                        As a user, I can search for data based on Temporal bounds
# 83  The tool allows exporting of search, download, and/or transformation references for use in programmatic access.
# 84                                                        As a user, I can search for data based on Temporal bounds
# 85                                                      As a user, I can acquire data via direct download in the UI
# 86                                                                       As a user, I can bulk download search data
# 87  The tool allows exporting of search, download, and/or transformation references for use in programmatic access.
# 88                                                        The UI allows for data spatial subsetting transformations
# 89                                                     The UI allows for data  temporal subsetting transformations?
# 90                                          The UI allows for data  band/layer/variable subsetting transformations?
# 91                                               The UI allows the reformatting of output files into other formats.
# 92                                                                 Ability to bulk download customized output files
# 93                                                                      Ability to re-submit the exact same request
# 94                                                           As a user, I can complete all tasks within the tool UX
